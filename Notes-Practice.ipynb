# %% [markdown]
# ![practice.jpg](attachment:practice.jpg)

# %% [markdown]
# ## Messing with Functions
# - Just trying to refamiliarize myself with some of the fundamentals in python.

# %%
def simple():
    me = 'Patrick\'s'
    print (me + " first function!")

# %%
simple()
# Out:
# Patrick's first function!

# %%
simple()
# Out:
# Patrick's first function!

# %%
def next_fun(a):
    return a + 10

# %%
next_fun(2)
# Out:
# 12

# %%
def simple_1(a):
    me = 'Patrick\'s'
    #print(me + " first function!")
    return a + 6
print('me')
simple_1(5)
# Out:
# me
# 11

# %%
simple_1(5)
# Out:
# 11

# %% [markdown]
# ## Built in Functions

# %%
float(3)
# Out:
# 3.0

# %%
max(10, 20, 30)
# Out:
# 30

# %%
min(10, 20, 30)
# Out:
# 10

# %%
z = -20
abs(z)
# Out:
# 20

# %%
list_1 = [1, 2, 3, 4]

# %%
sum(list_1)
# Out:
# 10

# %%
round(3.5555, 2)
# Out:
# 3.56

# %%
round(3.75)
# Out:
# 4

# %%
2 ** 10
# Out:
# 1024

# %%
pow(2, 10)
# Out:
# 1024

# %%
len("Mathematics")
# Out:
# 11

# %% [markdown]
# ## Working with Lists
# - How to call on lists.

# %%
dic = {"friend": ['Patrick', 'Roger'], "other": 'Steve'}

# %%
dic['friend'][1]
# Out:
# 'Roger'

# %%
del dic['friend'][1]

# %%
dic
# Out:
# {'friend': ['Patrick'], 'other': 'Steve'}

# %%
family = ['Daniel', 'Thomas', 'Patrick', 'Molly']
family
# Out:
# ['Daniel', 'Thomas', 'Patrick', 'Molly']

# %%
family[2]
# Out:
# 'Patrick'

# %% [markdown]
# ## Methods
# - Working with different data types.
# - Applying methods to them.
# - A method, like a function, is a set of instructions that perform a task.
#  - The difference is that a method is associated with an object, while a function is not
